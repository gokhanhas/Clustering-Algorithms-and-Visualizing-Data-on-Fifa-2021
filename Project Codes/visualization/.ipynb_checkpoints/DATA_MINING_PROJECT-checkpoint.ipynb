# %%
# Gökhan Has - 161044067
# Data Mining Project
# @01.01.2021

# %%
# for dataset operations
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler

#for data visualizations
import matplotlib.pyplot as plt
import hdbscan
from sklearn import metrics
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # reading dataset #

# %%
data = pd.read_csv('fifa21.csv', index_col=0)
data.head(5)
# Out:
#            Name  Age  OVA            Nationality           Club  BOV   BP  \
# ID
# 2   G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 27      J. Cole   33   71                England  Coventry City   71  CAM
# 36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#         Position                                       Player Photo  \
# ID
# 2             LM  https://cdn.sofifa.com/players/000/002/16_120.png
# 16    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png
# 27  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png
# 36           NaN  https://cdn.sofifa.com/players/000/036/09_120.png
# 41        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png
#
#                                            Club Logo  ...    CDM    RDM  \
# ID                                                    ...
# 2       https://cdn.sofifa.com/teams/55/light_60.png  ...  70+-1  70+-1
# 16    https://cdn.sofifa.com/teams/2013/light_60.png  ...   66+1   66+1
# 27    https://cdn.sofifa.com/teams/1800/light_60.png  ...   54+0   54+0
# 36     https://cdn.sofifa.com/teams/106/light_60.png  ...   65+0   65+0
# 41  https://cdn.sofifa.com/teams/101146/light_60.png  ...   73+3   73+3
#
#       RWB     LB   LCB    CB   RCB     RB    GK Gender
# ID
# 2   71+-2  70+-1  69+0  69+0  69+0  70+-1  17+0   Male
# 16   62+1   60+1  60+1  60+1  60+1   60+1  17+1   Male
# 27   52+0   47+0  46+0  46+0  46+0   47+0  15+0   Male
# 36   56+0   57+0  51+0  51+0  51+0   57+0  22+0   Male
# 41   70+3   67+3  64+3  64+3  64+3   67+3  17+3   Male
#
# [5 rows x 106 columns]

# %%
# maas bilgilerini ceviren fonksiyon
def convert_money(val):
    result = val.replace('€', '')
    if 'M' in result:
        result = float(result.replace('M', ''))*1000000
    elif 'K' in result:
        result = float(result.replace('K', ''))*1000
    return float(result)

# %%
# maas bilgilerini teker teker düzenleme islemi
data['Value'] = data['Value'].apply(lambda x: convert_money(x))
data['Wage'] = data['Wage'].apply(lambda x: convert_money(x))

data[['Value','Wage']].head()
# Out:
#         Value     Wage
# ID
# 2    625000.0   7000.0
# 16   600000.0   7000.0
# 27  1100000.0  15000.0
# 36        0.0      0.0
# 41  5500000.0  12000.0

# %%
# veriyi temizleme islemi gerekli, çünkü maas bilgileri 0 olan oyuncular bulunmakta
data = data[(data['Value'] != 0) | (data['Wage'] != 0)]

# %%
# bundan sonraki islemler yedek veri üzerinden yapılacaktır. Cunkü veri görselleştirmede kullanılacaktır.
backup_data = data.dropna(subset=['Position'])[['Name', 'Position', 'OVA', 'BOV'] + data.select_dtypes('float64').columns.tolist()]
backup_data.head()
# Out:
#            Name      Position  OVA  BOV      Value     Wage  Volleys  Curve  \
# ID
# 2   G. Pasquale            LM   69   71   625000.0   7000.0     58.0   65.0
# 16  Luis García    CM CAM CDM   71   70   600000.0   7000.0     68.0   79.0
# 27      J. Cole  CAM RM RW LM   71   71  1100000.0  15000.0     75.0   84.0
# 41      Iniesta        CM CAM   81   82  5500000.0  12000.0     79.0   80.0
# 61   D. Odonkor         RW RM   66   66   725000.0   5000.0     57.0   61.0
#
#     Agility  Balance  Jumping  Interceptions  Positioning  Vision  Composure  \
# ID
# 2      68.0     68.0     68.0           69.0         63.0    66.0        NaN
# 16     62.0     72.0     54.0           71.0         72.0    73.0       79.0
# 27     71.0     75.0     58.0           39.0         69.0    74.0        NaN
# 41     79.0     75.0     40.0           70.0         78.0    93.0       89.0
# 61     75.0     85.0     70.0           26.0         63.0    58.0        NaN
#
#     Sliding Tackle
# ID
# 2             69.0
# 16            40.0
# 27            30.0
# 41            56.0
# 61            31.0

# %%
# değeri en düşük ile en fazla olan oyuncuların değerleri
backup_data['Value'].min(), backup_data['Value'].max()
# Out:
# (0.0, 105500000.0)

# %%
# maaşı en düşük ile en fazla olan oyuncuların değerleri
backup_data['Wage'].min(), backup_data['Wage'].max()
# Out:
# (0.0, 560000.0)

# %%
# Standart Scaler İşlemleri
scaler = StandardScaler()
backup_data['Value'] = scaler.fit_transform(backup_data['Value'].values.reshape(-1, 1))
backup_data['Wage'] = scaler.fit_transform(backup_data['Wage'].values.reshape(-1, 1))

# %%
# scaler dan sonra değeri en düşük ile en fazla olan oyuncuların değerleri
backup_data['Value'].min(), backup_data['Value'].max()
# Out:
# (-0.48780889311623127, 18.77707275578192)

# %%
# scaler den sonra maaşı en düşük ile en fazla olan oyuncuların değerleri
backup_data['Wage'].min(), backup_data['Wage'].max()
# Out:
# (-0.5022012209051251, 25.5555307881074)

# %%
# Veri temizleme islemi
for col in data.select_dtypes('float64'):
    if col != 'Value' and col != 'Wage':
        backup_data[col] = pd.qcut(backup_data[col], 10, labels=False, duplicates='drop')

# %%
backup_data.head()
# Out:
#            Name      Position  OVA  BOV     Value      Wage  Volleys  Curve  \
# ID
# 2   G. Pasquale            LM   69   71 -0.373680 -0.176480        7      7
# 16  Luis García    CM CAM CDM   71   70 -0.378246 -0.176480        9      9
# 27      J. Cole  CAM RM RW LM   71   71 -0.286943  0.195774        9      9
# 41      Iniesta        CM CAM   81   82  0.516521  0.056179        9      9
# 61   D. Odonkor         RW RM   66   66 -0.355420 -0.269543        7      6
#
#     Agility  Balance  Jumping  Interceptions  Positioning  Vision  Composure  \
# ID
# 2         5        5        5              8            6       7        NaN
# 16        3        6        1              8            8       9        9.0
# 27        6        7        2              3            8       9        NaN
# 41        8        7        0              8            9       9        9.0
# 61        7        9        6              2            6       5        NaN
#
#     Sliding Tackle
# ID
# 2                8
# 16               3
# 27               3
# 41               5
# 61               3

# %% [markdown]
# # VISUALIZATION #

# %%
# Futbolcuların Kullandığı Ayaklar

plt.rcParams['figure.figsize'] = (10, 5)
sns.countplot(data['foot'], palette = 'pink')
plt.title('Futbolcuların Kullandığı Ayaklar', fontsize = 20)
plt.show()

# %%
# mevkisine göre oyuncu sayıları

plt.figure(figsize = (18, 8))
plt.style.use('fivethirtyeight')
ax = sns.countplot('BP', data = data, palette = 'bone')
ax.set_xlabel(xlabel = 'Oyun Pozisyonları', fontsize = 16)
ax.set_ylabel(ylabel = 'Oyuncu Sayıları', fontsize = 16)
ax.set_title(label = 'Mevkisine Göre Oyuncular', fontsize = 20)
plt.show()

# %%
# Ülkesine göre futbolcular

#plt.style.use('dark_background')
data['Nationality'].value_counts().head(80).plot.bar(color = 'red', figsize = (20, 7))
plt.title('Ülkelere Göre Futbolcu Sayısı', fontsize = 30, fontweight = 20)
plt.xlabel('Ülke İsimleri')
plt.ylabel('Futbolcu Sayıları')
plt.show()

# %%
# Aldıkları maaşa göre futbolcu grafiği

plt.rcParams['figure.figsize'] = (15, 5)
sns.distplot(data['Wage'], color = 'blue')
plt.xlabel('Maaş aralıkları', fontsize = 16)
plt.ylabel('Oyuncu Sayıları', fontsize = 16)
plt.title('Maaşa Göre Oyuncu Bilgileri', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %%
# Overall değerlerine göre oyuncu sayıları

plt.figure(figsize = (20, 10))
ax = sns.countplot(x = 'OVA', data = data, palette = 'pastel')
ax.set_title(label = 'Overall Değerlerine Göre Oyuncu Sayıları', fontsize = 20)
ax.set_xlabel(xlabel = 'Overall Değerleri', fontsize = 16)
ax.set_ylabel(ylabel = 'Oyuncu Sayıları', fontsize = 16)
plt.show()

# %%
# Oyuncuların boyları ...

plt.figure(figsize = (13, 8))
ax = sns.countplot(x = 'Height', data = data, palette = 'dark')
ax.set_title(label = 'Boylarına Göre Oyuncular', fontsize = 20)
ax.set_xlabel(xlabel = 'Boy (inch)', fontsize = 16)
ax.set_ylabel(ylabel = 'Oyuncu Sayıları', fontsize = 16)
plt.show()

# %%
# Oyuncuların kiloları ...

data['Weight'] = data['Weight'].apply(lambda x: x.replace('lbs',''))

plt.figure(figsize = (15, 5))
sns.distplot(data['Weight'], color = 'pink')
plt.title('Oyuncu Kiloları', fontsize = 20)
plt.xlabel('Kilo (lbs)', fontsize = 16)
plt.ylabel('Oyuncu Sayıları', fontsize = 16)
plt.show()

# %%
# Oyuncuların Atak Puanlarının Gösterilmesi

plt.figure(figsize = (15, 7))

sns.countplot(x = 'Attacking', data = data, palette = 'hls')
plt.title('Atak Puanlarına Göre Oyuncular', fontsize = 20)
plt.xlabel('Oyuncuların Atak Puanları', fontsize = 16)
plt.ylabel('Oyuncu Sayıları', fontsize = 16)
plt.show()

# %%
# Oyuncuların potansiyel puanlarının histogramı

x = data.POT
plt.figure(figsize=(12,8))
plt.style.use('seaborn-paper')

ax = sns.distplot(x, bins = 58, kde = False, color = 'y')
ax.set_xlabel(xlabel = "Oyuncuların Potansiyel Puanları", fontsize = 16)
ax.set_ylabel(ylabel = 'Oyuncu Sayıları', fontsize = 16)
ax.set_title(label = 'Oyuncuların Potansiyel Puan Histogramı', fontsize = 20)
plt.show()

# %%
# Oyuncuların genel puanlarının histogramı

sns.set(style = "dark", palette = "deep", color_codes = True)
x = data.OVA
plt.figure(figsize = (12,8))
plt.style.use('ggplot')

ax = sns.distplot(x, bins = 52, kde = False, color = 'r')
ax.set_xlabel(xlabel = "Oyuncu Overall Puanları", fontsize = 16)
ax.set_ylabel(ylabel = 'Oyuncu Sayıları', fontsize = 16)
ax.set_title(label = 'Oyuncu Overall Puan Histogramı', fontsize = 20)
plt.show()

# %%
# Hangi oyuncuların yaşlarının aynı olduğunun gösterimi

sns.set(style = "dark", palette = "colorblind", color_codes = True)
x = data.Age
plt.figure(figsize = (15,8))
ax = sns.distplot(x, bins = 58, kde = False, color = 'g')
ax.set_xlabel(xlabel = "Yaş", fontsize = 16)
ax.set_ylabel(ylabel = 'Oyuncu Sayıları', fontsize = 16)
ax.set_title(label = 'Oyuncu Yaşları Histogramı', fontsize = 20)
plt.show()

# %%
# Genel Skorların (Overall) ve Tercih Edilen Ayak Yaşına Göre Karşılaştırılması

plt.rcParams['figure.figsize'] = (18, 7)
plt.style.use('seaborn-dark-palette')

sns.boxenplot(data['OVA'], data['Age'], hue = data['foot'], palette = 'Greys')
plt.title('Genel Skorların (Overall) ve Tercih Edilen Ayak Yaşına Göre Karşılaştırılması', fontsize = 20)
plt.show()

# %%
# Korelasyon ateş grafiği, oyuncuların puan özelliklerinden oluşturulmuştur

plt.rcParams['figure.figsize'] = (30, 20)
sns.heatmap(data[['Age', 'Nationality', 'OVA', 'POT', 'Value',
                'Release Clause', 'foot', 'Attacking', 'Crossing', 'Finishing', 'Heading Accuracy',
                'Short Passing', 'Volleys', 'Skill', 'Dribbling', 'Curve', 'FK Accuracy', 'Long Passing',
                'Ball Control', 'Movement', 'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
                'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots', 'Mentality', 'Aggression',
                'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
                'Sliding Tackle', 'Goalkeeping'
                 ]].corr(), annot = True)

plt.title('Veri Kümesindeki Oyuncu Özelliklerin Histogramı', fontsize = 30)
plt.show()

# %%
# Genel puanlarına göre yaşları, kulüpleri ve milliyetleri ile her pozisyon için en iyi oyuncular

data.loc[data.groupby(data['BP'])['OVA'].idxmax()][['BP', 'Name', 'Age', 'Club', 'Nationality']]
# Out:
#          BP                 Name  Age                 Club     Nationality
# ID
# 192985  CAM         K. De Bruyne   29      Manchester City         Belgium
# 203376   CB          V. van Dijk   28            Liverpool     Netherlands
# 200145  CDM             Casemiro   28          Real Madrid          Brazil
# 165153   CF           K. Benzema   32          Real Madrid          France
# 182521   CM             T. Kroos   30          Real Madrid         Germany
# 200389   GK             J. Oblak   27      Atlético Madrid        Slovenia
# 216267   LB         A. Robertson   26            Liverpool        Scotland
# 200104   LM               H. Son   27    Tottenham Hotspur  Korea Republic
# 190871   LW            Neymar Jr   28  Paris Saint-Germain          Brazil
# 164169  LWB          Filipe Luís   32      Atlético Madrid          Brazil
# 231281   RB  T. Alexander-Arnold   21            Liverpool         England
# 206113   RM            S. Gnabry   24    FC Bayern München         Germany
# 158023   RW             L. Messi   33         FC Barcelona       Argentina
# 121939  RWB              P. Lahm   32    FC Bayern München         Germany
# 20801    ST    Cristiano Ronaldo   35             Juventus        Portugal

# %%
# Potansiyel puanlarına göre yaş, milliyet ve kulüp ile her pozisyondan en iyi oyuncular

data.loc[data.groupby(data['BP'])['POT'].idxmax()][['BP', 'Name', 'Age', 'Club', 'Nationality']]
# Out:
#          BP                 Name  Age                 Club  Nationality
# ID
# 233049  CAM            J. Sancho   20    Borussia Dortmund      England
# 235243   CB           M. de Ligt   20             Juventus  Netherlands
# 212622  CDM           J. Kimmich   25    FC Bayern München      Germany
# 165153   CF           K. Benzema   32          Real Madrid       France
# 241096   CM            S. Tonali   20                Milan        Italy
# 192448   GK        M. ter Stegen   28         FC Barcelona      Germany
# 216267   LB         A. Robertson   26            Liverpool     Scotland
# 222492   LM              L. Sané   24    FC Bayern München      Germany
# 190871   LW            Neymar Jr   28  Paris Saint-Germain       Brazil
# 210035  LWB             Grimaldo   24           SL Benfica        Spain
# 231281   RB  T. Alexander-Arnold   21            Liverpool      England
# 238794   RM         Vinícius Jr.   19          Real Madrid       Brazil
# 158023   RW             L. Messi   33         FC Barcelona    Argentina
# 121939  RWB              P. Lahm   32    FC Bayern München      Germany
# 231747   ST            K. Mbappé   21  Paris Saint-Germain       France

# %%
# Genel puanlarını karşılaştırmak için en yüksek oyuncu sayısına sahip ülkeleri seçmek

data['Nationality'].value_counts().head(8)
# Out:
# England        1703
# Germany        1149
# Spain          1119
# France          982
# Brazil          839
# Argentina       774
# Italy           560
# Netherlands     467
# Name: Nationality, dtype: int64

# %%
# Her Ulusun Oyuncusu ve genel puanları

some_countries = ('England', 'Germany', 'Spain', 'Argentina', 'France', 'Brazil', 'Italy', 'Turkey')
data_countries = data.loc[data['Nationality'].isin(some_countries) & data['OVA']]

plt.rcParams['figure.figsize'] = (15, 7)
ax = sns.barplot(x = data_countries['Nationality'], y = data_countries['OVA'], palette = 'spring')
ax.set_xlabel(xlabel = 'Ülkeler', fontsize = 9)
ax.set_ylabel(ylabel = 'Overall Puanları', fontsize = 9)
ax.set_title(label = 'Farklı ülkelerden oyuncuların genel skorlarının (overall) dağılımı', fontsize = 20)
plt.show()

# %%
# Her ulusun oyuncuları ve onların ücretleri

some_countries = ('England', 'Germany', 'Spain', 'Argentina', 'France', 'Brazil', 'Italy', 'Turkey')
data_countries = data.loc[data['Nationality'].isin(some_countries) & data['Wage']]

plt.rcParams['figure.figsize'] = (15, 7)
ax = sns.barplot(x = data_countries['Nationality'], y = data_countries['Wage'], palette = 'Purples')
ax.set_xlabel(xlabel = 'Ülkeler', fontsize = 9)
ax.set_ylabel(ylabel = 'Maaşlar', fontsize = 9)
ax.set_title(label = 'Farklı ülkelerden oyuncuların maaşların dağılımı', fontsize = 15)
plt.show()

# %%
# Her Ulusun Oyuncusu ve büyümesi

some_countries = ('England', 'Germany', 'Spain', 'Argentina', 'France', 'Brazil', 'Italy', 'Turkey')
data_countries = data.loc[data['Nationality'].isin(some_countries) & data['Growth']]

plt.rcParams['figure.figsize'] = (15, 7)
ax = sns.boxenplot(x = data_countries['Nationality'], y = data_countries['Growth'], palette = 'autumn')
ax.set_xlabel(xlabel = 'Ülkeler', fontsize = 9)
ax.set_ylabel(ylabel = 'Büyüme Oranları', fontsize = 9)
ax.set_title(label = 'Ülkelere göre oyuncuların büyüme oranları', fontsize = 15)
plt.show()

# %%
# dünyadaki popüler kulüpleri bulmak

data['Club'].value_counts().head(10)
# Out:
# Bolton Wanderers           45
# Chelsea                    44
# Arsenal                    43
# Wolverhampton Wanderers    43
# Everton                    43
# Aston Villa                43
# AS Monaco                  43
# Crystal Palace             42
# Sunderland                 42
# Sparta Praha               42
# Name: Club, dtype: int64

# %%
some_clubs = ('CD Leganés', 'Southampton', 'RC Celta', 'Empoli', 'Fortuna Düsseldorf', 'Manchestar City',
             'Tottenham Hotspur', 'FC Barcelona', 'Valencia CF', 'Chelsea', 'Real Madrid', 'Fenerbahçe SK')

data_clubs = data.loc[data['Club'].isin(some_clubs) & data['OVA']]

plt.rcParams['figure.figsize'] = (15, 8)
ax = sns.boxplot(x = data_clubs['Club'], y = data_clubs['OVA'], palette = 'inferno')
ax.set_xlabel(xlabel = 'Bazı popüler klübler', fontsize = 9)
ax.set_ylabel(ylabel = 'Overall Puanları', fontsize = 9)
ax.set_title(label = 'Farklı Popüler Kulüplerde Toplam Skorun Dağılımı', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %%
# Bazı Popüler Kulüplerde Yaş Dağılımı

some_clubs = ('CD Leganés', 'Southampton', 'RC Celta', 'Empoli', 'Fortuna Düsseldorf', 'Manchestar City',
             'Tottenham Hotspur', 'FC Barcelona', 'Valencia CF', 'Chelsea', 'Real Madrid', 'Fenerbahçe SK')

data_club = data.loc[data['Club'].isin(some_clubs) & data['Wage']]

plt.rcParams['figure.figsize'] = (15, 8)
ax = sns.boxenplot(x = 'Club', y = 'Age', data = data_club, palette = 'magma')
ax.set_xlabel(xlabel = 'Bazı popüler klübler', fontsize = 10)
ax.set_ylabel(ylabel = 'Yaş Dağılımı', fontsize = 10)
ax.set_title(label = 'Bazı Popüler Kulüplerde Yaş Dağılımı', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %%
data_club = data.loc[data['Club'].isin(some_clubs) & data['Wage']]

plt.rcParams['figure.figsize'] = (16, 8)
ax = sns.boxplot(x = 'Club', y = 'Wage', data = data_club, palette = 'Reds')
ax.set_xlabel(xlabel = 'Bazı popüler klübler', fontsize = 10)
ax.set_ylabel(ylabel = 'Maaş Dağılımları', fontsize = 10)
ax.set_title(label = 'Bazı Popüler Kulüplerde Maaş Dağılımı', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %%
data_club = data.loc[data['Club'].isin(some_clubs) & data['Growth']]

plt.rcParams['figure.figsize'] = (16, 8)
ax = sns.violinplot(x = 'Club', y = 'Growth', data = data_club, palette = 'bright')
ax.set_xlabel(xlabel = 'Bazı popüler klübler', fontsize = 10)
ax.set_ylabel(ylabel = 'Oyuncuların büyüme dağılımları', fontsize = 10)
ax.set_title(label = 'Bazı popüler klüblerde oyuncuların büyüme oranları dağılımı', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %%
data_clubs = data.loc[data['Club'].isin(some_clubs) & data['BOV']]

plt.rcParams['figure.figsize'] = (15, 8)
ax = sns.violinplot(x = 'Club', y = 'BOV', data = data_clubs, palette = 'PuBu')
ax.set_xlabel(xlabel = 'Bazı popüler klübler', fontsize = 9)
ax.set_ylabel(ylabel = 'Kilo (lbs)', fontsize = 9)
ax.set_title(label = 'Farklı Popüler Kulüplerde Oyuncuların Kilo Dağılımı', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %%
# Veri kümesindeki en genç 15 oyuncuyu bulmak

youngest = data.sort_values('Age', ascending = True)[['Name', 'Age', 'Club', 'Nationality']].head(15)
youngest
# Out:
#                        Name  Age                    Club     Nationality
# ID
# 252750             V. Covil   16     Forest Green Rovers   United States
# 247866            C. Miszta   16          Legia Warszawa          Poland
# 255558            E. Bayram   16          Galatasaray SK          Turkey
# 247962        M. Williamsen   16         Kristiansund BK          Norway
# 256970           A. Karabec   16            Sparta Praha  Czech Republic
# 247025         T. Gulliksen   16         Strømsgodset IF          Norway
# 257023          P. Johansen   16      Sandefjord Fotball          Norway
# 252255              Barredo   16         SD Ponferradina           Spain
# 251314         S. McKinstry   16            Leeds United        Scotland
# 257042          U. Bertelli   16  Olympique de Marseille          France
# 253403  R. Borges Rodrigues   16       Melbourne City FC       Australia
# 255120            N. Kenneh   16            Leeds United         England
# 257090          I. Doukouré   16         Valenciennes FC          France
# 257130              A. Hoff   16              AC Horsens         Denmark
# 251202               A. Vik   16            Rosenborg BK          Norway

# %%
# Veri kümesindeki en yaşlı 15 oyuncuyu bulmak

eldest = data.sort_values('Age', ascending = False)[['Name', 'Age', 'Club', 'Nationality']].head(15)
eldest
# Out:
#                 Name  Age                Club   Nationality
# ID
# 254704      K. Miura   53         Yokohama FC         Japan
# 53985       S. Royce   47          Gillingham       England
# 208927  H. Sulaimani   43             Al Ahli  Saudi Arabia
# 169108     L. Butrón   43        Alianza Lima          Peru
# 135708     C. Blanco   42        Club América        Mexico
# 684     M. Schwarzer   42      Leicester City     Australia
# 1179       G. Buffon   42            Juventus         Italy
# 143743  F. Mondragón   42            Colombia      Colombia
# 153260        Hilton   42     Montpellier HSC        Brazil
# 254196  L. Fernández   42            SD Aucas      Colombia
# 29552    S. Nakamura   42         Yokohama FC         Japan
# 156483  C. Lucchetti   42    Atlético Tucumán     Argentina
# 110638     Cifuentes   41            Cádiz CF         Spain
# 104900     M. Gurski   41  SpVgg Unterhaching       Germany
# 2702      K. Ellison   41      Newport County       England

# %%
# Veri kümesindeki oyuncuların klüblerine katılma sütununa bakma

data['Joined'].head()
# Out:
# ID
# 2      Jul 1, 2008
# 16    Jul 19, 2014
# 27     Jan 7, 2016
# 41    Jul 16, 2018
# 61     Jan 1, 2011
# Name: Joined, dtype: object

# %%
# Klüblerinde en uzun süre oynayan ilk 10 oyuncu

import datetime

now = datetime.datetime.now()
data['Join_year'] = data.Joined.dropna().map(lambda x: x.split(',')[1].split(' ')[1])
data['Years_of_member'] = (data.Join_year.dropna().map(lambda x: now.year - int(x))).astype('int')
membership = data[['Name', 'Club', 'Years_of_member']].sort_values(by = 'Years_of_member', ascending = False).head(10)
membership.set_index('Name', inplace=True)
membership
# Out:
#                                 Club  Years_of_member
# Name
# R. Giggs           Manchester United               31
# Rogério Ceni               São Paulo               29
# F. Totti                        Roma               28
# P. Scholes         Manchester United               28
# J. Zanetti                     Inter               26
# J. Carragher               Liverpool               25
# H. Sogahata          Kashima Antlers               23
# L. King            Tottenham Hotspur               23
# Xavi                    FC Barcelona               23
# Manuel Pablo  Deportivo de La Coruña               23

# %%
# oyuncuların özelliklerini tanımlamak

player_features = ('Acceleration', 'Aggression', 'Agility', 
                   'Balance', 'Ball Control', 'Composure', 
                   'Crossing', 'Dribbling', 'FK Accuracy', 
                   'Finishing', 'GK Diving', 'GK Handling', 
                   'GK Kicking', 'GK Positioning', 'GK Reflexes', 
                   'Heading Accuracy', 'Interceptions', 'Jumping', 
                   'Long Passing', 'Long Shots', 'Marking', 'Penalties')

# Top four features for every position in football

for i, val in data.groupby(data['Position'])[player_features].mean().iterrows():
    print('Position {}: {}, {}, {}'.format(i, *tuple(val.nlargest(4).index)))
# Out:
# Position ACB: Jumping, FK Accuracy, Aggression
# Position CAM: Balance, Agility, Acceleration
# Position CAM CDM: Balance, Agility, Ball Control
# Position CAM CDM CM: Balance, Ball Control, Long Passing
# Position CAM CDM LM: Acceleration, Agility, Balance
# Position CAM CF: Balance, Agility, Acceleration
# Position CAM CF CM: Ball Control, Long Shots, Finishing
# Position CAM CF LM: Agility, Acceleration, Jumping
# Position CAM CF LW: Penalties, Composure, Dribbling
# Position CAM CF RM: Agility, Balance, Acceleration
# Position CAM CF RW: FK Accuracy, Penalties, Agility
# Position CAM CF ST: Agility, Dribbling, Acceleration
# Position CAM CM: Balance, Agility, Ball Control
# Position CAM CM CDM: Balance, Agility, Acceleration
# Position CAM CM CF: Ball Control, Dribbling, Agility
# Position CAM CM LM: Agility, Balance, Acceleration
# Position CAM CM LM RM: Composure, Agility, Acceleration
# Position CAM CM LW: Agility, Balance, Dribbling
# Position CAM CM RM: Balance, Agility, Ball Control
# Position CAM CM RW: Balance, Ball Control, Dribbling
# Position CAM CM ST: Ball Control, Acceleration, Dribbling
# Position CAM LB: Ball Control, Balance, Agility
# Position CAM LB LM: Long Shots, Crossing, Ball Control
# Position CAM LM: Balance, Agility, Acceleration
# Position CAM LM CF: Agility, Acceleration, Balance
# Position CAM LM CM: Agility, Balance, Ball Control
# Position CAM LM LB: Agility, Acceleration, Ball Control
# Position CAM LM LW: Balance, Agility, Acceleration
# Position CAM LM LWB LB: Balance, Agility, Acceleration
# Position CAM LM RM: Agility, Balance, Acceleration
# Position CAM LM RW: FK Accuracy, Long Shots, Balance
# Position CAM LM ST: Agility, Acceleration, Balance
# Position CAM LW: Agility, Balance, Dribbling
# Position CAM LW CF: Agility, Acceleration, Jumping
# Position CAM LW CM: Balance, Agility, Ball Control
# Position CAM LW LM: Agility, Ball Control, Dribbling
# Position CAM LW RW: Balance, Agility, Acceleration
# Position CAM LW RW CM: Balance, Ball Control, Dribbling
# Position CAM LW ST: Agility, Balance, Acceleration
# Position CAM RB: Acceleration, Agility, Balance
# Position CAM RM: Balance, Agility, Acceleration
# Position CAM RM CF: Dribbling, Ball Control, Agility
# Position CAM RM CM: Agility, Ball Control, Balance
# Position CAM RM LM: Agility, Balance, Acceleration
# Position CAM RM LM ST: FK Accuracy, Long Shots, Balance
# Position CAM RM LW: Acceleration, Agility, Dribbling
# Position CAM RM RB: Acceleration, Balance, Agility
# Position CAM RM RW: Agility, Ball Control, Acceleration
# Position CAM RM RW LM: Crossing, Dribbling, Ball Control
# Position CAM RM ST: Agility, Ball Control, Dribbling
# Position CAM RW: Balance, Agility, Acceleration
# Position CAM RW CF: Agility, Balance, Acceleration
# Position CAM RW CM: Agility, Acceleration, Balance
# Position CAM RW LM: Acceleration, Agility, Aggression
# Position CAM RW LW: Balance, Agility, Acceleration
# Position CAM RW RM: Acceleration, Balance, Agility
# Position CAM RW ST: Penalties, Ball Control, Balance
# Position CAM RWB CM: Acceleration, Agility, Balance
# Position CAM ST: Balance, Agility, Acceleration
# Position CAM ST CF: Dribbling, Agility, Ball Control
# Position CAM ST CM: Balance, Acceleration, Agility
# Position CAM ST LM: Agility, Acceleration, Balance
# Position CAM ST LW: Acceleration, Agility, Balance
# Position CAM ST RM: Acceleration, Agility, Balance
# Position CAM ST RW: Agility, Ball Control, Dribbling
# Position CB: Jumping, Aggression, Heading Accuracy
# Position CB CAM: Jumping, Heading Accuracy, Ball Control
# Position CB CDM: Jumping, Aggression, Interceptions
# Position CB CDM CM: Jumping, Aggression, Heading Accuracy
# Position CB CDM LB: Jumping, Composure, Interceptions
# Position CB CDM RB: Jumping, Acceleration, Marking
# Position CB CM: Jumping, Aggression, Marking
# Position CB CM CDM: Aggression, Jumping, Balance
# Position CB LB: Jumping, Aggression, Marking
# Position CB LB CDM: Aggression, Jumping, Interceptions
# Position CB LB LWB: Jumping, Marking, Aggression
# Position CB LB RB: Jumping, Aggression, Interceptions
# Position CB LM: Acceleration, Balance, Crossing
# Position CB LWB: Jumping, Acceleration, Balance
# Position CB RB: Jumping, Aggression, Interceptions
# Position CB RB CDM: Jumping, Acceleration, Heading Accuracy
# Position CB RB CM: Jumping, Aggression, Agility
# Position CB RB LB: Jumping, Aggression, Marking
# Position CB RB RM: Jumping, Agility, Marking
# Position CB RB RWB: Jumping, Acceleration, Marking
# Position CB RB ST: Agility, Aggression, Jumping
# Position CB RM RB: Acceleration, Jumping, Aggression
# Position CB RWB: Jumping, Interceptions, Marking
# Position CB RWB RB: Jumping, Aggression, Agility
# Position CB RWB RM: Jumping, Acceleration, Agility
# Position CB ST: Jumping, Balance, Composure
# Position CB ST CAM: Aggression, Heading Accuracy, Composure
# Position CDM: Aggression, Balance, Jumping
# Position CDM CAM: Agility, Ball Control, Long Passing
# Position CDM CAM CM: Agility, Jumping, Ball Control
# Position CDM CAM LM: Agility, Balance, Ball Control
# Position CDM CB: Aggression, Jumping, Interceptions
# Position CDM CB CM: Aggression, Interceptions, Jumping
# Position CDM CB LB: Jumping, Aggression, Balance
# Position CDM CB RB: Jumping, Ball Control, Interceptions
# Position CDM CB RM: Aggression, Jumping, Crossing
# Position CDM CM: Aggression, Ball Control, Interceptions
# Position CDM CM CAM: Balance, Aggression, Long Passing
# Position CDM CM CB: Aggression, Jumping, Interceptions
# Position CDM CM LB: Aggression, Ball Control, Long Passing
# Position CDM CM LM: Long Passing, Jumping, Ball Control
# Position CDM CM RB: Aggression, Balance, Interceptions
# Position CDM CM RM: Balance, Aggression, Agility
# Position CDM CM RM RWB: Interceptions, FK Accuracy, Ball Control
# Position CDM CM RW: Acceleration, Agility, Penalties
# Position CDM CM RWB: Balance, Aggression, Jumping
# Position CDM LB: Balance, Acceleration, Agility
# Position CDM LB CB: Agility, Acceleration, Balance
# Position CDM LB LM: FK Accuracy, Balance, Long Shots
# Position CDM LM: Ball Control, Jumping, Long Passing
# Position CDM LWB LB: Crossing, Composure, Interceptions
# Position CDM RB: Jumping, Balance, Acceleration
# Position CDM RB CB: Jumping, Acceleration, Aggression
# Position CDM RB CM: Balance, Jumping, Aggression
# Position CDM RB LB: Balance, Agility, Aggression
# Position CDM RB RM: Aggression, Jumping, Acceleration
# Position CDM RM: Agility, Balance, Acceleration
# Position CDM RM RB: Acceleration, Agility, Balance
# Position CDM RWB: Balance, Jumping, Agility
# Position CF: Balance, Acceleration, Dribbling
# Position CF CAM: Acceleration, Agility, Balance
# Position CF CAM CM: Ball Control, Agility, Dribbling
# Position CF CAM LM: Dribbling, Jumping, Ball Control
# Position CF CAM LW: Balance, Agility, Acceleration
# Position CF CAM RW: Acceleration, Agility, Ball Control
# Position CF CAM ST: Balance, Jumping, Ball Control
# Position CF CM: Agility, Balance, Ball Control
# Position CF CM LM: Acceleration, Agility, Ball Control
# Position CF LM: Balance, Ball Control, Agility
# Position CF LM CAM: Ball Control, Dribbling, Agility
# Position CF LM LW: Balance, Ball Control, Dribbling
# Position CF LM RM: Acceleration, Agility, Balance
# Position CF LW: Acceleration, Agility, Balance
# Position CF LW CAM: Ball Control, Dribbling, Crossing
# Position CF LW RW: Acceleration, Agility, Dribbling
# Position CF LW ST: Acceleration, Agility, Dribbling
# Position CF RM: Acceleration, Agility, Balance
# Position CF RM RW: Agility, Balance, Acceleration
# Position CF RM ST: Acceleration, Agility, Balance
# Position CF RW: Agility, Balance, Acceleration
# Position CF RW LW: Acceleration, Agility, Dribbling
# Position CF ST: Agility, Dribbling, Acceleration
# Position CF ST CAM: Agility, Ball Control, Dribbling
# Position CF ST CM: Balance, Jumping, Acceleration
# Position CF ST LM: Agility, Balance, Acceleration
# Position CF ST LW: Acceleration, Agility, Finishing
# Position CF ST RM: Agility, Balance, Acceleration
# Position CF ST RW: Balance, Agility, Ball Control
# Position CM: Balance, Agility, Acceleration
# Position CM CAM: Balance, Agility, Ball Control
# Position CM CAM CDM: Ball Control, Balance, Agility
# Position CM CAM CF: Ball Control, Dribbling, Acceleration
# Position CM CAM LB: Balance, Agility, Jumping
# Position CM CAM LM: Agility, Balance, Ball Control
# Position CM CAM LW: Agility, Balance, Acceleration
# Position CM CAM RB: Balance, Acceleration, Jumping
# Position CM CAM RM: Balance, Agility, Ball Control
# Position CM CAM RM CDM: Composure, Ball Control, Balance
# Position CM CAM RW: Agility, Balance, Acceleration
# Position CM CAM RW RM: Crossing, Penalties, Long Passing
# Position CM CAM ST: Dribbling, Ball Control, Long Passing
# Position CM CB: Jumping, Balance, Acceleration
# Position CM CB CDM: Composure, Ball Control, Long Passing
# Position CM CDM: Balance, Ball Control, Long Passing
# Position CM CDM CAM: Ball Control, Long Passing, Balance
# Position CM CDM CB: Aggression, Ball Control, Long Passing
# Position CM CDM LB: Balance, Agility, Acceleration
# Position CM CDM LM: Ball Control, Agility, Dribbling
# Position CM CDM LM CAM: Aggression, Agility, Marking
# Position CM CDM LW: Aggression, Ball Control, Dribbling
# Position CM CDM RB: Balance, Aggression, Ball Control
# Position CM CDM RM: Agility, Balance, Ball Control
# Position CM CDM ST: Balance, Ball Control, Long Passing
# Position CM CF: Ball Control, Dribbling, Long Passing
# Position CM CF CAM: Balance, Acceleration, Agility
# Position CM CF RM: Ball Control, Dribbling, Interceptions
# Position CM LB: Balance, Agility, Acceleration
# Position CM LB LM: Jumping, Crossing, Long Passing
# Position CM LM: Balance, Agility, Acceleration
# Position CM LM CAM: Agility, Balance, Ball Control
# Position CM LM CB: Acceleration, Jumping, Balance
# Position CM LM CDM: Balance, Ball Control, Agility
# Position CM LM LB: Ball Control, Long Shots, Dribbling
# Position CM LM LW: Acceleration, Agility, Balance
# Position CM LM RM: Agility, Ball Control, Balance
# Position CM LM RW: Jumping, Balance, Agility
# Position CM LM ST: Acceleration, Dribbling, Balance
# Position CM LW: Agility, Balance, Acceleration
# Position CM LW CAM: Balance, Agility, Dribbling
# Position CM LW LM: Agility, Balance, Dribbling
# Position CM LW ST: FK Accuracy, Crossing, Balance
# Position CM LWB: Balance, Jumping, Aggression
# Position CM RB: Balance, Agility, Acceleration
# Position CM RB CDM: Balance, Interceptions, Aggression
# Position CM RB LB: Penalties, Composure, Crossing
# Position CM RB LM: Agility, Composure, Crossing
# Position CM RB RM: Acceleration, Balance, Agility
# Position CM RM: Balance, Agility, Acceleration
# Position CM RM CAM: Agility, Balance, Acceleration
# Position CM RM CDM: Balance, Agility, Ball Control
# Position CM RM LM: Agility, Ball Control, Balance
# Position CM RM LW: Agility, Acceleration, Jumping
# Position CM RM RB: Agility, Acceleration, Balance
# Position CM RM RW: Acceleration, Agility, Balance
# Position CM RM RWB: Balance, Dribbling, Ball Control
# Position CM RM ST: Aggression, Ball Control, Composure
# Position CM RW: Balance, Agility, Acceleration
# Position CM RW CAM: Agility, Balance, Ball Control
# Position CM RW LW: Ball Control, Dribbling, Balance
# Position CM RW ST: Aggression, Composure, Ball Control
# Position CM RWB: Agility, Acceleration, Balance
# Position CM ST: Acceleration, Balance, Agility
# Position CM ST CDM: Jumping, Agility, Penalties
# Position GK: GK Reflexes, GK Diving, GK Positioning
# Position GK RB: GK Reflexes, GK Diving, GK Positioning
# Position IILB: Acceleration, Agility, Balance
# Position IIRM: Balance, Acceleration, Agility
# Position IVST RM CF: Acceleration, Agility, Balance
# Position LB: Acceleration, Balance, Agility
# Position LB CAM: Acceleration, Agility, Balance
# Position LB CB: Jumping, Acceleration, Aggression
# Position LB CB CDM: Balance, Acceleration, Jumping
# Position LB CB LM: Acceleration, Jumping, Crossing
# Position LB CB LWB: Jumping, Aggression, Crossing
# Position LB CB RB: Acceleration, Agility, Jumping
# Position LB CDM: Balance, Acceleration, Agility
# Position LB CDM CB: Acceleration, Agility, Jumping
# Position LB CDM CM CB: Aggression, Jumping, Marking
# Position LB CM: Balance, Jumping, Agility
# Position LB CM LM: Agility, Balance, Crossing
# Position LB CM LW: Balance, Acceleration, Agility
# Position LB CM RB: Acceleration, Agility, Dribbling
# Position LB CM ST: Balance, Agility, Acceleration
# Position LB LM: Acceleration, Agility, Balance
# Position LB LM CAM: Agility, Acceleration, Composure
# Position LB LM CB: Jumping, Aggression, Crossing
# Position LB LM CDM: Balance, FK Accuracy, Acceleration
# Position LB LM CM: Balance, Acceleration, Dribbling
# Position LB LM LW: Jumping, Balance, Agility
# Position LB LM LWB: Acceleration, Agility, Crossing
# Position LB LM RB: Jumping, Acceleration, Agility
# Position LB LM RM: Acceleration, Balance, Agility
# Position LB LW: Acceleration, Balance, Agility
# Position LB LW CM: Aggression, Acceleration, Agility
# Position LB LW LM: Acceleration, Agility, Balance
# Position LB LW RW: Acceleration, Agility, Dribbling
# Position LB LWB: Acceleration, Agility, Jumping
# Position LB LWB CB: Acceleration, Aggression, Crossing
# Position LB LWB CDM: Acceleration, Ball Control, Composure
# Position LB LWB CM: Balance, Acceleration, Agility
# Position LB LWB LM: Acceleration, Agility, Balance
# Position LB LWB LW: Acceleration, Jumping, Balance
# Position LB LWB RB: Acceleration, Agility, Aggression
# Position LB RB: Acceleration, Balance, Agility
# Position LB RB CB: Acceleration, Jumping, Balance
# Position LB RB CDM: Acceleration, Agility, Balance
# Position LB RB CM: Acceleration, Agility, Balance
# Position LB RB LM: Acceleration, Agility, Balance
# Position LB RB LWB: Acceleration, Jumping, Aggression
# Position LB RB RM: Balance, Jumping, Acceleration
# Position LB RB RWB: Acceleration, Dribbling, Aggression
# Position LB RM: Acceleration, Agility, Balance
# Position LM: Acceleration, Agility, Balance
# Position LM CAM: Balance, Acceleration, Agility
# Position LM CAM CDM: Ball Control, Dribbling, Acceleration
# Position LM CAM CF: Balance, Agility, Dribbling
# Position LM CAM CM: Agility, Dribbling, Acceleration
# Position LM CAM CM CF: Ball Control, Dribbling, Composure
# Position LM CAM LB: Agility, Balance, Acceleration
# Position LM CAM LW: Balance, Agility, Acceleration
# Position LM CAM RM: Agility, Acceleration, Balance
# Position LM CAM ST: Agility, Acceleration, Balance
# Position LM CDM: Balance, Jumping, Agility
# Position LM CF: Agility, Acceleration, Dribbling
# Position LM CF CAM: Agility, Balance, Jumping
# Position LM CF RM: Acceleration, Dribbling, Long Shots
# Position LM CF ST: Acceleration, Agility, Jumping
# Position LM CM: Agility, Acceleration, Balance
# Position LM CM CAM: Balance, Agility, Dribbling
# Position LM CM CDM: Acceleration, Agility, Ball Control
# Position LM CM LB: Acceleration, Balance, Agility
# Position LM CM RM: Agility, Acceleration, Dribbling
# Position LM CM RW: Agility, Balance, Dribbling
# Position LM LB: Acceleration, Balance, Agility
# Position LM LB CDM: Jumping, Acceleration, Aggression
# Position LM LB CF: Balance, Agility, Acceleration
# Position LM LB CM: Acceleration, Agility, Ball Control
# Position LM LB LW: Acceleration, Agility, Balance
# Position LM LB LWB: Agility, Balance, Jumping
# Position LM LB RB: Acceleration, Dribbling, Ball Control
# Position LM LB RM: Acceleration, Balance, Jumping
# Position LM LW: Acceleration, Agility, Balance
# Position LM LW CAM: Agility, Acceleration, Balance
# Position LM LW CF: Balance, Acceleration, Agility
# Position LM LW LB: Acceleration, Balance, Agility
# Position LM LW RM: Acceleration, Balance, Agility
# Position LM LW RM RW: Agility, Balance, Acceleration
# Position LM LW RW: Agility, Acceleration, Balance
# Position LM LW ST: Acceleration, Agility, Dribbling
# Position LM LWB: Acceleration, Balance, Agility
# Position LM LWB CB: Acceleration, Crossing, Jumping
# Position LM LWB LB: Acceleration, Agility, Dribbling
# Position LM LWB RW: Acceleration, Agility, Balance
# Position LM LWB ST: Acceleration, Agility, Jumping
# Position LM RB LB: Crossing, Dribbling, Ball Control
# Position LM RM: Acceleration, Agility, Balance
# Position LM RM CAM: Agility, Balance, Acceleration
# Position LM RM CB: Heading Accuracy, Acceleration, Aggression
# Position LM RM CF: Agility, Acceleration, Balance
# Position LM RM CM: Agility, Balance, Acceleration
# Position LM RM LB: Agility, Acceleration, Balance
# Position LM RM LW: Acceleration, Agility, Balance
# Position LM RM LWB: Acceleration, Agility, Balance
# Position LM RM RB: Acceleration, Agility, Balance
# Position LM RM RW: Acceleration, Agility, Balance
# Position LM RM ST: Acceleration, Agility, Balance
# Position LM RW: Acceleration, Agility, Balance
# Position LM RW LW: Acceleration, Agility, Dribbling
# Position LM RW RM: Acceleration, Agility, Dribbling
# Position LM RWB RM: Acceleration, Crossing, Agility
# Position LM ST: Acceleration, Agility, Balance
# Position LM ST CAM: Agility, Balance, Acceleration
# Position LM ST CF: Balance, Acceleration, Agility
# Position LM ST CM: Jumping, Agility, Acceleration
# Position LM ST LB: Acceleration, Agility, Ball Control
# Position LM ST LW: Acceleration, Agility, Balance
# Position LM ST RM: Acceleration, Agility, Balance
# Position LM ST RW: Acceleration, Jumping, Agility
# Position LW: Acceleration, Agility, Balance
# Position LW CAM: Agility, Balance, Acceleration
# Position LW CAM CF: Balance, Agility, Acceleration
# Position LW CAM CM: Agility, Dribbling, Ball Control
# Position LW CAM LM: Agility, Balance, Acceleration
# Position LW CAM RM: Balance, Acceleration, Agility
# Position LW CAM RW: Balance, Agility, Acceleration
# Position LW CAM RW LM: Acceleration, Jumping, Aggression
# Position LW CAM ST: Agility, Acceleration, Balance
# Position LW CF: Agility, Acceleration, Balance
# Position LW CF LM: Acceleration, Agility, Penalties
# Position LW CF RW: Acceleration, Agility, Balance
# Position LW CF ST: Acceleration, Dribbling, Agility
# Position LW CM: Balance, Ball Control, Agility
# Position LW LB: Acceleration, Balance, Agility
# Position LW LB CAM: FK Accuracy, Dribbling, Ball Control
# Position LW LB LM: Acceleration, Agility, Balance
# Position LW LM: Acceleration, Agility, Balance
# Position LW LM CAM: Acceleration, Balance, Agility
# Position LW LM CF: Acceleration, Dribbling, Ball Control
# Position LW LM LB: Agility, Crossing, Acceleration
# Position LW LM RM: Balance, Agility, Acceleration
# Position LW LM ST: Acceleration, Agility, Dribbling
# Position LW LWB: Acceleration, Agility, Balance
# Position LW LWB RWB: Agility, Balance, Acceleration
# Position LW RM CF: Agility, Acceleration, Dribbling
# Position LW RM RW: Acceleration, Agility, Balance
# Position LW RW: Acceleration, Agility, Balance
# Position LW RW CAM: Agility, Acceleration, Dribbling
# Position LW RW CF: Agility, Balance, Acceleration
# Position LW RW CM: Dribbling, Agility, Ball Control
# Position LW RW LM: Acceleration, Agility, Dribbling
# Position LW RW RM: Agility, Acceleration, Balance
# Position LW RW ST: Acceleration, Agility, Balance
# Position LW ST: Acceleration, Agility, Balance
# Position LW ST CAM: Dribbling, Aggression, Ball Control
# Position LW ST CM: Acceleration, Agility, Balance
# Position LW ST LM: Agility, Acceleration, Dribbling
# Position LW ST RW: Acceleration, Agility, Balance
# Position LWB: Acceleration, Balance, Agility
# Position LWB CB: Acceleration, Balance, Jumping
# Position LWB CM: Agility, Balance, Acceleration
# Position LWB LB: Acceleration, Balance, Agility
# Position LWB LB CB: Acceleration, Jumping, Marking
# Position LWB LB LM: Acceleration, Agility, Balance
# Position LWB LM: Acceleration, Agility, Balance
# Position LWB LM CM: Crossing, Aggression, Balance
# Position LWB LM LB: Acceleration, Balance, Penalties
# Position LWB LM RB: Balance, Agility, Acceleration
# Position LWB LM RM: Agility, Composure, Acceleration
# Position LWB LM RWB: Balance, Agility, Acceleration
# Position LWB LW: Acceleration, Agility, Crossing
# Position LWB RM LB: FK Accuracy, Crossing, Long Shots
# Position LWB RWB: Jumping, Balance, Acceleration
# Position ND LB RB: Balance, Acceleration, Agility
# Position RB: Acceleration, Balance, Agility
# Position RB CB: Jumping, Acceleration, Agility
# Position RB CB CDM: Acceleration, Jumping, Agility
# Position RB CB LB: Acceleration, Agility, Jumping
# Position RB CB RM: Acceleration, Jumping, Agility
# Position RB CB RWB: Jumping, Acceleration, Balance
# Position RB CDM: Acceleration, Agility, Balance
# Position RB CDM CM: Interceptions, Marking, Balance
# Position RB CDM RM: Jumping, Aggression, Agility
# Position RB CM: Agility, Acceleration, Balance
# Position RB CM CAM: Acceleration, Agility, Balance
# Position RB CM CB: Acceleration, Jumping, Ball Control
# Position RB CM CDM: Acceleration, Agility, Jumping
# Position RB CM LB: Acceleration, Balance, Agility
# Position RB CM RM: Acceleration, Balance, Agility
# Position RB CM RWB: Acceleration, Agility, Balance
# Position RB LB: Acceleration, Balance, Agility
# Position RB LB CB: Jumping, Balance, Acceleration
# Position RB LB CDM: Balance, Agility, Acceleration
# Position RB LB RM: Acceleration, Agility, Balance
# Position RB LB RWB: Acceleration, Agility, Aggression
# Position RB LM: Balance, Agility, Acceleration
# Position RB LM LB: Acceleration, Agility, Dribbling
# Position RB LM RM: Balance, Agility, Jumping
# Position RB LWB: Acceleration, Jumping, Agility
# Position RB RM: Acceleration, Agility, Balance
# Position RB RM CAM: Acceleration, Jumping, Agility
# Position RB RM CB: Acceleration, Agility, Crossing
# Position RB RM CDM: Agility, Acceleration, Balance
# Position RB RM CM: Acceleration, Agility, Dribbling
# Position RB RM LB: Balance, Agility, Acceleration
# Position RB RM LM: Agility, Acceleration, Balance
# Position RB RM RW: Acceleration, Agility, Balance
# Position RB RM RWB: Acceleration, Balance, Agility
# Position RB RM ST: Acceleration, Balance, Agility
# Position RB RW: Acceleration, Agility, Balance
# Position RB RW LB: Acceleration, Dribbling, Ball Control
# Position RB RWB: Acceleration, Agility, Balance
# Position RB RWB CB: Acceleration, Jumping, Agility
# Position RB RWB CDM: Agility, Balance, Acceleration
# Position RB RWB CM: Jumping, Balance, Acceleration
# Position RB RWB LB: Balance, Acceleration, Agility
# Position RB RWB LWB: Acceleration, Balance, Agility
# Position RB RWB RM: Acceleration, Agility, Balance
# Position RB RWB RW: Acceleration, Dribbling, Balance
# Position RB ST CB: Acceleration, Heading Accuracy, Agility
# Position RM: Acceleration, Agility, Balance
# Position RM CAM: Agility, Balance, Acceleration
# Position RM CAM CF: Balance, Agility, Acceleration
# Position RM CAM CM: Balance, Agility, Dribbling
# Position RM CAM LM: Acceleration, Agility, Balance
# Position RM CAM RB: Jumping, Acceleration, Dribbling
# Position RM CAM RW: Balance, Agility, Acceleration
# Position RM CAM ST: Agility, Acceleration, Balance
# Position RM CDM: Acceleration, Agility, Balance
# Position RM CF: Agility, Balance, Acceleration
# Position RM CF CAM: Acceleration, Agility, Balance
# Position RM CF LM: Balance, Composure, Dribbling
# Position RM CF ST: Jumping, Acceleration, Balance
# Position RM CM: Acceleration, Agility, Balance
# Position RM CM CAM: Balance, Agility, Acceleration
# Position RM CM CDM: Balance, Acceleration, Agility
# Position RM CM LM: Agility, Acceleration, Balance
# Position RM CM RB: Acceleration, Agility, Balance
# Position RM CM ST: Acceleration, Agility, Jumping
# Position RM LB: Balance, Agility, Jumping
# Position RM LB RB: Crossing, Acceleration, Ball Control
# Position RM LM: Acceleration, Agility, Balance
# Position RM LM CAM: Agility, Acceleration, Balance
# Position RM LM CAM RW: Agility, Acceleration, Dribbling
# Position RM LM CDM: Balance, Agility, Crossing
# Position RM LM CF: Agility, Acceleration, Balance
# Position RM LM CM: Acceleration, Balance, Agility
# Position RM LM LB: Acceleration, Balance, Agility
# Position RM LM LW: Agility, Acceleration, Balance
# Position RM LM LWB: Acceleration, Agility, Balance
# Position RM LM RB: Acceleration, Agility, Balance
# Position RM LM RW: Acceleration, Agility, Balance
# Position RM LM RW LW: Acceleration, Agility, Balance
# Position RM LM RW ST: Ball Control, Dribbling, Agility
# Position RM LM RWB: Agility, Balance, Acceleration
# Position RM LM ST: Acceleration, Agility, Balance
# Position RM LW: Acceleration, Agility, Balance
# Position RM LW CAM: Agility, Balance, Acceleration
# Position RM LW RW: Acceleration, Agility, Balance
# Position RM LW ST: Acceleration, Jumping, Penalties
# Position RM LWB: Balance, Aggression, Crossing
# Position RM RB: Acceleration, Balance, Agility
# Position RM RB CAM: Agility, Acceleration, Balance
# Position RM RB CB: Jumping, Aggression, Crossing
# Position RM RB CM: Balance, Ball Control, Dribbling
# Position RM RB LB: Acceleration, Jumping, Ball Control
# Position RM RB LM: Acceleration, Agility, Balance
# Position RM RB RWB: Acceleration, Agility, Balance
# Position RM RB ST: Aggression, Jumping, Crossing
# Position RM RW: Acceleration, Agility, Balance
# Position RM RW CAM: Agility, Acceleration, Balance
# Position RM RW CF: Acceleration, Agility, Balance
# Position RM RW CM: Acceleration, Agility, Balance
# Position RM RW LM: Acceleration, Agility, Dribbling
# Position RM RW LW: Agility, Acceleration, Balance
# Position RM RW RB: Acceleration, Aggression, Jumping
# Position RM RW ST: Acceleration, Agility, Balance
# Position RM RWB: Acceleration, Agility, Balance
# Position RM RWB CAM: Crossing, Aggression, Ball Control
# Position RM RWB LM: Agility, Acceleration, Balance
# Position RM RWB RB: Crossing, Dribbling, Acceleration
# Position RM RWB ST: Acceleration, Agility, Jumping
# Position RM ST: Acceleration, Agility, Balance
# Position RM ST CAM: Balance, Acceleration, Agility
# Position RM ST CF: Agility, Balance, Acceleration
# Position RM ST LM: Acceleration, Agility, Balance
# Position RM ST LM RW: Agility, Jumping, Acceleration
# Position RM ST LW: Agility, Balance, Acceleration
# Position RM ST RW: Acceleration, Agility, Dribbling
# Position RW: Acceleration, Agility, Balance
# Position RW CAM: Balance, Agility, Acceleration
# Position RW CAM CM: Dribbling, Agility, Ball Control
# Position RW CAM LM: Acceleration, Agility, Finishing
# Position RW CAM LW: Balance, Acceleration, Dribbling
# Position RW CAM RM: Agility, Balance, Acceleration
# Position RW CAM ST: Acceleration, Agility, Balance
# Position RW CF: Agility, Acceleration, Balance
# Position RW CF CAM: Balance, Dribbling, Ball Control
# Position RW CF LW: Balance, Long Shots, Ball Control
# Position RW CM: Balance, Acceleration, Agility
# Position RW CM CAM: Ball Control, Dribbling, Acceleration
# Position RW CM LW: Penalties, Ball Control, Dribbling
# Position RW LB: Jumping, Acceleration, Dribbling
# Position RW LM: Acceleration, Agility, Jumping
# Position RW LM CAM: Acceleration, Agility, Balance
# Position RW LM LW: Acceleration, Agility, Balance
# Position RW LM ST: Agility, Balance, Acceleration
# Position RW LW: Acceleration, Agility, Balance
# Position RW LW CAM: Acceleration, Balance, Agility
# Position RW LW CF: Acceleration, Agility, Balance
# Position RW LW LM: Acceleration, Agility, Balance
# Position RW LW RB: Agility, Balance, Acceleration
# Position RW LW RM: Acceleration, Balance, Agility
# Position RW LW RWB: Balance, Agility, Aggression
# Position RW LW ST: Acceleration, Agility, Balance
# Position RW LWB LW: Acceleration, Agility, Finishing
# Position RW LWB RM: Agility, Balance, Acceleration
# Position RW RB: Acceleration, Agility, Balance
# Position RW RB LB: Acceleration, Agility, Dribbling
# Position RW RB RM: Acceleration, Agility, Balance
# Position RW RM: Acceleration, Agility, Balance
# Position RW RM CAM: Agility, Balance, Acceleration
# Position RW RM CF: Acceleration, Dribbling, Aggression
# Position RW RM LM: Acceleration, Agility, FK Accuracy
# Position RW RM LW: Agility, Balance, Acceleration
# Position RW RM RB: Aggression, Jumping, Acceleration
# Position RW RM ST: Acceleration, Agility, Dribbling
# Position RW RWB: Acceleration, Dribbling, Balance
# Position RW ST: Acceleration, Agility, Balance
# Position RW ST CAM: Acceleration, Agility, Balance
# Position RW ST CF: Acceleration, Agility, Balance
# Position RW ST LW: Acceleration, Agility, Balance
# Position RW ST RM: Agility, Acceleration, Jumping
# Position RWB: Acceleration, Agility, Balance
# Position RWB CAM: Agility, Aggression, Composure
# Position RWB CB: Acceleration, Balance, Jumping
# Position RWB CB LWB: Jumping, Acceleration, Agility
# Position RWB CDM: Jumping, Aggression, Balance
# Position RWB CM: Acceleration, Agility, Balance
# Position RWB CM RM: Agility, Acceleration, Jumping
# Position RWB LM: Acceleration, Balance, Agility
# Position RWB LWB: Acceleration, Agility, Balance
# Position RWB RB: Acceleration, Balance, Jumping
# Position RWB RB CB: Jumping, Acceleration, Agility
# Position RWB RB LB: Crossing, Penalties, Acceleration
# Position RWB RB LWB: Acceleration, Agility, Balance
# Position RWB RB RM: Acceleration, Crossing, Composure
# Position RWB RM: Acceleration, Agility, Balance
# Position RWB RM LWB: Acceleration, Agility, Balance
# Position RWB RM RB: Acceleration, Jumping, Balance
# Position RWB RW: Acceleration, Balance, Agility
# Position RWB ST: Acceleration, Balance, Agility
# Position ST: Jumping, Finishing, Acceleration
# Position ST CAM: Ball Control, Finishing, Acceleration
# Position ST CAM CF: Agility, Balance, Acceleration
# Position ST CAM CM: Agility, Acceleration, Jumping
# Position ST CAM LM: Acceleration, Balance, Agility
# Position ST CAM LW: Agility, Acceleration, Balance
# Position ST CAM RM: Acceleration, Agility, Balance
# Position ST CAM RW: Jumping, Ball Control, Finishing
# Position ST CB: Jumping, Aggression, Balance
# Position ST CB CDM: Balance, Aggression, Acceleration
# Position ST CB RB: Aggression, Acceleration, Balance
# Position ST CF: Acceleration, Finishing, Jumping
# Position ST CF CAM: Finishing, Composure, Dribbling
# Position ST CF LM: Jumping, Agility, Acceleration
# Position ST CF LM CAM: Dribbling, Acceleration, Agility
# Position ST CF LW: Agility, Balance, Acceleration
# Position ST CF RM: Acceleration, Agility, Ball Control
# Position ST CF RW: Acceleration, Aggression, Agility
# Position ST CM: Jumping, Acceleration, Agility
# Position ST CM CAM: Agility, Balance, Acceleration
# Position ST LM: Acceleration, Agility, Jumping
# Position ST LM CAM: Balance, Acceleration, Agility
# Position ST LM CF: Acceleration, Jumping, Ball Control
# Position ST LM LW: Acceleration, Agility, Balance
# Position ST LM RB: Ball Control, Finishing, Long Shots
# Position ST LM RM: Acceleration, Agility, Balance
# Position ST LM RW: Acceleration, Agility, Dribbling
# Position ST LW: Acceleration, Agility, Jumping
# Position ST LW CAM: Acceleration, Agility, Balance
# Position ST LW CF: Acceleration, Agility, Ball Control
# Position ST LW LM: Acceleration, Agility, Balance
# Position ST LW LWB: Agility, Balance, Jumping
# Position ST LW RM: Acceleration, Agility, Balance
# Position ST LW RW: Acceleration, Agility, Balance
# Position ST RB RM: Acceleration, Aggression, Agility
# Position ST RM: Acceleration, Agility, Jumping
# Position ST RM CAM: Acceleration, Dribbling, Finishing
# Position ST RM CF: Finishing, Ball Control, Dribbling
# Position ST RM LM: Acceleration, Agility, Dribbling
# Position ST RM LW: Acceleration, Agility, Balance
# Position ST RM RB: Acceleration, Balance, Agility
# Position ST RM RW: Acceleration, Balance, Agility
# Position ST RM RWB: Acceleration, Ball Control, Finishing
# Position ST RW: Acceleration, Agility, Jumping
# Position ST RW CAM: Acceleration, Balance, Jumping
# Position ST RW CAM RM: Aggression, Jumping, Heading Accuracy
# Position ST RW CF: Balance, Acceleration, Jumping
# Position ST RW LM: Acceleration, Agility, Balance
# Position ST RW LW: Acceleration, Agility, Jumping
# Position ST RW RM: Acceleration, Agility, Dribbling

# %%
"""
from math import pi

idx = 1
plt.figure(figsize=(15,45))
for position_name, features in data.groupby(data['Position'])[player_features].mean().iterrows():
    top_features = dict(features.nlargest(5))
    
    # değişken sayısı
    categories=top_features.keys()
    N = len(categories)

    # Veri çerçevesinin ilk satırını çizeceğiz.
    # Ancak dairesel grafiği kapatmak için ilk değeri tekrar etmemiz gerekiyor:
    values = list(top_features.values())
    values += values[:1]

    # Özelliklerin yazılması
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    # Örümcek ağı grafiği oluşturma
    ax = plt.subplot(9, 3, idx, polar=True)

    # Değişken başına bir eksen çizin + etiket etiketleri ekleyin
    plt.xticks(angles[:-1], categories, color='grey', size=8)

    # ylabels çizme
    ax.set_rlabel_position(0)
    plt.yticks([25,50,75], ["25","50","75"], color="grey", size=7)
    plt.ylim(0,100)
    
    plt.subplots_adjust(hspace = 0.5)
    
    # Plot data
    ax.plot(angles, values, linewidth=1, linestyle='solid')

    # alanı boyama
    ax.fill(angles, values, 'b', alpha=0.1)
    
    plt.title(position_name, size=11, y=1.1)
    idx += 1 
"""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-c3d545171235> in <module>
#      20
#      21     # Örümcek ağı grafiği oluşturma
# ---> 22     ax = plt.subplot(9, 3, idx, polar=True)
#      23
#      24     # Değişken başına bir eksen çizin + etiket etiketleri ekleyin
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1140
#    1141     fig = gcf()
# -> 1142     ax = fig.add_subplot(*args, **kwargs)
#    1143     bbox = ax.bbox
#    1144     axes_to_delete = []
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      37
#      38         self.figure = fig
# ---> 39         self._subplotspec = SubplotSpec._from_subplot_args(fig, args)
#      40         self.update_params()
#      41         # _axes_class is set in the subplot_class_factory
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     687                     num = int(num)
#     688                 if num < 1 or num > rows*cols:
# --> 689                     raise ValueError(
#     690                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#     691                 return gs[num - 1]   # -1 due to MATLAB indexing.
#
# ValueError: num must be 1 <= num <= 27, not 28

# %%
# En iyi 10 sol ayaklı futbolcu

data[data['foot'] == 'Left'][['Name', 'Age', 'Club', 'Nationality']].head(10)
# Out:
#                  Name  Age                  Club  Nationality
# ID
# 2         G. Pasquale   33               Udinese        Italy
# 80       E. Belözoğlu   38         Fenerbahçe SK       Turkey
# 241          R. Giggs   39     Manchester United        Wales
# 1040   Roberto Carlos   38  FC Anzhi Makhachkala       Brazil
# 2196  R. Weidenfeller   36     Borussia Dortmund      Germany
# 2492           Eliseu   33            SL Benfica     Portugal
# 2702       K. Ellison   41        Newport County      England
# 3712             Dida   39         Internacional       Brazil
# 5479         Casillas   38              FC Porto        Spain
# 5672        E. Davids   39                Barnet  Netherlands

# %%
# En iyi 10 sağ ayaklı futbolcu

data[data['foot'] == 'Right'][['Name', 'Age', 'Club', 'Nationality']].head(10)
# Out:
#               Name  Age               Club          Nationality
# ID
# 16     Luis García   37          KAS Eupen                Spain
# 27         J. Cole   33      Coventry City              England
# 41         Iniesta   36        Vissel Kobe                Spain
# 61      D. Odonkor   27   Alemannia Aachen              Germany
# 246     P. Scholes   37  Manchester United              England
# 249     P. Neville   35            Everton              England
# 330       R. Keane   35          LA Galaxy  Republic of Ireland
# 684   M. Schwarzer   42     Leicester City            Australia
# 1041    J. Zanetti   39              Inter            Argentina
# 1075  A. Del Piero   38          Sydney FC                Italy

# %%
# sol ve sağ ayaklı futbolcuların performansını karşılaştırma
# top kontrolü vs top sürme

sns.lmplot(x = 'Ball Control', y = 'Dribbling', data = data, col = 'foot')
plt.show()

# %%
# en fazla sayıda farklı ülkeye sahip kulüpleri görselleştirmek

data.groupby(data['Club'])['Nationality'].nunique().sort_values(ascending = False).head(10)
# Out:
# Club
# Lazio                  21
# PAOK                   21
# Liverpool              21
# Fulham                 21
# Leicester City         20
# Inter                  20
# Juventus               20
# Napoli                 20
# Nottingham Forest      19
# TSG 1899 Hoffenheim    19
# Name: Nationality, dtype: int64

# %%
# en az sayıda farklı ülkeye sahip kulüpleri görselleştirmek

data.groupby(data['Club'])['Nationality'].nunique().sort_values(ascending = True).head(10)
# Out:
# Club
# Santos              1
# Corinthians         1
# Coritiba            1
# Criciúma            1
# Curicó Unido        1
# Córdoba CF          1
# Côte d'Ivoire       1
# Cúcuta Deportivo    1
# Latina              1
# Sangju Sangmu FC    1
# Name: Nationality, dtype: int64

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'OVA', 'Nationality', 'Club', 'BOV', 'BP', 'Position',
#        'Player Photo', 'Club Logo',
#        ...
#        'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'GK', 'Gender', 'Join_year',
#        'Years_of_member'],
#       dtype='object', length=108)

# %%
# Yaş ve genel skorun karşılaştırılması

sns.lineplot(data['Age'], data['OVA'], palette = 'Wistia')
plt.title('Yaşa göre overall puanları', fontsize = 20)
plt.show()

# %%
import plotly.offline as py
from plotly.offline import init_notebook_mode, iplot

init_notebook_mode(connected = True)
import plotly.graph_objs as go
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Dünya haritasında oyuncuları görselleştirme
# Oyuncuların ülkelerine göre overall değerleri

rating = pd.DataFrame(data.groupby(['Nationality'])['OVA'].sum().reset_index())
count = pd.DataFrame(rating.groupby('Nationality')['OVA'].sum().reset_index())

trace = [go.Choropleth(
            colorscale = 'YlOrRd',
            locationmode = 'country names',
            locations = count['Nationality'],
            text = count['Nationality'],
            z = count['OVA'],
)]

layout = go.Layout(title = 'Oyuncuların ülkelerine göre overall değerleri')

fig = go.Figure(data = trace, layout = layout)
py.iplot(fig)
# Out:
# <div>                            <div id="d3abf46c-c7d8-4ce1-ab8e-845eb222e804" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3abf46c-c7d8-4ce1-ab8e-845eb222e804")) {                    Plotly.newPlot(                        "d3abf46c-c7d8-4ce1-ab8e-845eb222e804",                        [{"colorscale": [[0.0, "rgb(255,255,204)"], [0.125, "rgb(255,237,160)"], [0.25, "rgb(254,217,118)"], [0.375, "rgb(254,178,76)"], [0.5, "rgb(253,141,60)"], [0.625, "rgb(252,78,42)"], [0.75, "rgb(227,26,28)"], [0.875, "rgb(189,0,38)"], [1.0, "rgb(128,0,38)"]], "locationmode": "country names", "locations": ["Afghanistan", "Albania", "Algeria", "Andorra", "Angola", "Antigua &amp; Barbuda", "Argentina", "Armenia", "Aruba", "Australia", "Austria", "Azerbaijan", "Barbados", "Belarus", "Belgium", "Belize", "Benin", "Bermuda", "Bolivia", "Bosnia Herzegovina", "Brazil", "Brunei Darussalam", "Bulgaria", "Burkina Faso", "Burundi", "Cameroon", "Canada", "Cape Verde", "Central African Republic", "Chad", "Chile", "China PR", "Chinese Taipei", "Colombia", "Comoros", "Congo", "Costa Rica", "Croatia", "Cuba", "Curacao", "Cyprus", "Czech Republic", "DR Congo", "Denmark", "Dominican Republic", "Ecuador", "Egypt", "El Salvador", "England", "Equatorial Guinea", "Eritrea", "Estonia", "Faroe Islands", "Finland", "France", "Gabon", "Gambia", "Georgia", "Germany", "Ghana", "Gibraltar", "Greece", "Grenada", "Guam", "Guinea", "Guinea Bissau", "Guyana", "Haiti", "Honduras", "Hong Kong", "Hungary", "Iceland", "Indonesia", "Iran", "Iraq", "Israel", "Italy", "Ivory Coast", "Jamaica", "Japan", "Jordan", "Kazakhstan", "Kenya", "Korea DPR", "Korea Republic", "Kosovo", "Latvia", "Lebanon", "Liberia", "Libya", "Liechtenstein", "Lithuania", "Luxembourg", "Macau", "Madagascar", "Malawi", "Malaysia", "Mali", "Malta", "Mauritania", "Mexico", "Moldova", "Montenegro", "Montserrat", "Morocco", "Mozambique", "Namibia", "Netherlands", "New Caledonia", "New Zealand", "Nicaragua", "Niger", "Nigeria", "North Macedonia", "Northern Ireland", "Norway", "Palestine", "Panama", "Papua New Guinea", "Paraguay", "Peru", "Philippines", "Poland", "Portugal", "Puerto Rico", "Qatar", "Republic of Ireland", "Romania", "Russia", "Rwanda", "Saint Kitts and Nevis", "Saint Lucia", "Saudi Arabia", "Scotland", "Senegal", "Serbia", "Sierra Leone", "Singapore", "Slovakia", "Slovenia", "South Africa", "South Sudan", "Spain", "Sudan", "Suriname", "Sweden", "Switzerland", "Syria", "S\u00e3o Tom\u00e9 &amp; Pr\u00edncipe", "Tanzania", "Thailand", "Togo", "Trinidad &amp; Tobago", "Tunisia", "Turkey", "Uganda", "Ukraine", "United Arab Emirates", "United States", "Uruguay", "Uzbekistan", "Venezuela", "Vietnam", "Wales", "Zambia", "Zimbabwe"], "text": ["Afghanistan", "Albania", "Algeria", "Andorra", "Angola", "Antigua &amp; Barbuda", "Argentina", "Armenia", "Aruba", "Australia", "Austria", "Azerbaijan", "Barbados", "Belarus", "Belgium", "Belize", "Benin", "Bermuda", "Bolivia", "Bosnia Herzegovina", "Brazil", "Brunei Darussalam", "Bulgaria", "Burkina Faso", "Burundi", "Cameroon", "Canada", "Cape Verde", "Central African Republic", "Chad", "Chile", "China PR", "Chinese Taipei", "Colombia", "Comoros", "Congo", "Costa Rica", "Croatia", "Cuba", "Curacao", "Cyprus", "Czech Republic", "DR Congo", "Denmark", "Dominican Republic", "Ecuador", "Egypt", "El Salvador", "England", "Equatorial Guinea", "Eritrea", "Estonia", "Faroe Islands", "Finland", "France", "Gabon", "Gambia", "Georgia", "Germany", "Ghana", "Gibraltar", "Greece", "Grenada", "Guam", "Guinea", "Guinea Bissau", "Guyana", "Haiti", "Honduras", "Hong Kong", "Hungary", "Iceland", "Indonesia", "Iran", "Iraq", "Israel", "Italy", "Ivory Coast", "Jamaica", "Japan", "Jordan", "Kazakhstan", "Kenya", "Korea DPR", "Korea Republic", "Kosovo", "L ...
